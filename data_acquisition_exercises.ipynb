# %%
import requests
import pandas as pd

# %% [markdown]
# - Using the code from the lesson as a guide, create a dataframe named items that has all of the data for items.

# %%
response = requests.get('https://python.zach.lol/api/v1/items')
data = response.json()

# %%
data
# Out:
# {'payload': {'items': [{'item_brand': 'Riceland',
#     'item_id': 1,
#     'item_name': 'Riceland American Jazmine Rice',
#     'item_price': 0.84,
#     'item_upc12': '35200264013',
#     'item_upc14': '35200264013'},
#    {'item_brand': 'Caress',
#     'item_id': 2,
#     'item_name': 'Caress Velvet Bliss Ultra Silkening Beauty Bar - 6 Ct',
#     'item_price': 6.44,
#     'item_upc12': '11111065925',
#     'item_upc14': '11111065925'},
#    {'item_brand': 'Earths Best',
#     'item_id': 3,
#     'item_name': 'Earths Best Organic Fruit Yogurt Smoothie Mixed Berry',
#     'item_price': 2.43,
#     'item_upc12': '23923330139',
#     'item_upc14': '23923330139'},
#    {'item_brand': 'Boars Head',
#     'item_id': 4,
#     'item_name': 'Boars Head Sliced White American Cheese - 120 Ct',
#     'item_price': 3.14,
#     'item_upc12': '208528800007',
#     'item_upc14': '208528800007'},
#    {'item_brand': 'Back To Nature',
#     'item_id': 5,
# ...

# %%
data['payload']['next_page']
# Out:
# '/api/v1/items?page=2'

# %%
df = pd.DataFrame(data['payload']['items'])
df
# Out:
#                item_brand  item_id  \
# 0                Riceland        1
# 1                  Caress        2
# 2             Earths Best        3
# 3              Boars Head        4
# 4          Back To Nature        5
# 5            Sally Hansen        6
# 6      Twinings Of London        7
# 7           Lea & Perrins        8
# 8            Van De Kamps        9
# 9                   Ahold       10
# 10             Honest Tea       11
# 11                Mueller       12
# 12  Garnier Nutritioniste       13
# 13                Pamprin       14
# 14                  Suave       15
# 15             Burts Bees       16
# 16                  Ducal       17
# 17                 Scotch       18
# 18                Careone       19
# 19           Usda Produce       20
#
#                                             item_name  item_price  \
# 0                      Riceland American Jazmine Rice        0.84
# 1   Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# ...

# %%
base_url = 'https://python.zach.lol'

# %%
response2 = requests.get(base_url + data['payload']['next_page'])
data = response2.json()

# %%
df = pd.concat([df, pd.DataFrame(data['payload']['items'])]).reset_index()

# %%
df.shape
# Out:
# (40, 7)

# %%
data['payload']['next_page']

response2 = requests.get(base_url + data['payload']['next_page'])
data = response2.json()

# %%
df = pd.concat([df, pd.DataFrame(data['payload']['items'])]).reset_index()

# %%
df
# Out:
#     level_0  index              item_brand  item_id  \
# 0         0    0.0                Riceland        1
# 1         1    1.0                  Caress        2
# 2         2    2.0             Earths Best        3
# 3         3    3.0              Boars Head        4
# 4         4    4.0          Back To Nature        5
# 5         5    5.0            Sally Hansen        6
# 6         6    6.0      Twinings Of London        7
# 7         7    7.0           Lea & Perrins        8
# 8         8    8.0            Van De Kamps        9
# 9         9    9.0                   Ahold       10
# 10       10   10.0              Honest Tea       11
# 11       11   11.0                 Mueller       12
# 12       12   12.0   Garnier Nutritioniste       13
# 13       13   13.0                 Pamprin       14
# 14       14   14.0                   Suave       15
# 15       15   15.0              Burts Bees       16
# 16       16   16.0                   Ducal       17
# ...

# %%
df.shape
# Out:
# (50, 8)

# %% [markdown]
# - Do the same thing, but for stores.

# %%
url = 'https://python.zach.lol/api/v1/stores'
respose = requests.get(url)

# %%
data = respose.json()

# %%
stores_df = pd.DataFrame(data['payload']['stores'])
stores_df
# Out:
#              store_address   store_city  store_id store_state store_zipcode
# 0   12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 1         9255 FM 471 West  San Antonio         2          TX         78251
# 2  2118 Fredericksburg Rdj  San Antonio         3          TX         78201
# 3          516 S Flores St  San Antonio         4          TX         78204
# 4          1520 Austin Hwy  San Antonio         5          TX         78218
# 5       1015 S WW White Rd  San Antonio         6          TX         78220
# 6   12018 Perrin Beitel Rd  San Antonio         7          TX         78217
# 7      15000 San Pedro Ave  San Antonio         8          TX         78232
# 8       735 SW Military Dr  San Antonio         9          TX         78221
# 9     8503 NW Military Hwy  San Antonio        10          TX         78231

# %% [markdown]
# - Extract the data for sales. There are a lot of pages of data here, so your code will need to be a little more complex. Your code should continue fetching data from the next page until all of the data is extracted.

# %%
url = 'https://python.zach.lol/api/v1/sales'
respose = requests.get(url)

# %%
data = respose.json()

# %%
sales_df = pd.DataFrame(data['payload']['sales'])
sales_df
# Out:
#       item  sale_amount                      sale_date  sale_id  store
# 0        1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1        1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2        1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3        1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4        1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...    ...          ...                            ...      ...    ...
# 4995     1         23.0  Mon, 05 Sep 2016 00:00:00 GMT     4996      3
# 4996     1         22.0  Tue, 06 Sep 2016 00:00:00 GMT     4997      3
# 4997     1         21.0  Wed, 07 Sep 2016 00:00:00 GMT     4998      3
# 4998     1         22.0  Thu, 08 Sep 2016 00:00:00 GMT     4999      3
# 4999     1         24.0  Fri, 09 Sep 2016 00:00:00 GMT     5000      3
#
# [5000 rows x 5 columns]

# %%
for i in range(2, 184):
    next_page = f'/api/v1/sales?page={i}'
next_page
# Out:
# '/api/v1/sales?page=183'

# %%
# for i in range(2,184):
#     base_url = 'https://python.zach.lol'
#     next_page = f'/api/v1/sales?page={i}'
#     data = requests.get(base_url + data['payload']['next_page']).json()
#     sales_df = pd.concat([sales_df, pd.DataFrame(data['payload']['sales'])])
# # sales_df.to_csv('sales_df')

# %%
import pandas as pd

# %%
# sales_df.to_csv('sales_df')

# %%
df
# Out:
#     level_0  index              item_brand  item_id  \
# 0         0    0.0                Riceland        1
# 1         1    1.0                  Caress        2
# 2         2    2.0             Earths Best        3
# 3         3    3.0              Boars Head        4
# 4         4    4.0          Back To Nature        5
# 5         5    5.0            Sally Hansen        6
# 6         6    6.0      Twinings Of London        7
# 7         7    7.0           Lea & Perrins        8
# 8         8    8.0            Van De Kamps        9
# 9         9    9.0                   Ahold       10
# 10       10   10.0              Honest Tea       11
# 11       11   11.0                 Mueller       12
# 12       12   12.0   Garnier Nutritioniste       13
# 13       13   13.0                 Pamprin       14
# 14       14   14.0                   Suave       15
# 15       15   15.0              Burts Bees       16
# 16       16   16.0                   Ducal       17
# ...

# %%
stores_df
# Out:
#              store_address   store_city  store_id store_state store_zipcode
# 0   12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 1         9255 FM 471 West  San Antonio         2          TX         78251
# 2  2118 Fredericksburg Rdj  San Antonio         3          TX         78201
# 3          516 S Flores St  San Antonio         4          TX         78204
# 4          1520 Austin Hwy  San Antonio         5          TX         78218
# 5       1015 S WW White Rd  San Antonio         6          TX         78220
# 6   12018 Perrin Beitel Rd  San Antonio         7          TX         78217
# 7      15000 San Pedro Ave  San Antonio         8          TX         78232
# 8       735 SW Military Dr  San Antonio         9          TX         78221
# 9     8503 NW Military Hwy  San Antonio        10          TX         78231

# %%
sales_df
# Out:
#       item  sale_amount                      sale_date  sale_id  store
# 0        1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1        1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2        1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3        1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4        1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...    ...          ...                            ...      ...    ...
# 2995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     10
# 2996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     10
# 2997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     10
# 2998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     10
# 2999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     10
#
# [913000 rows x 5 columns]

# %%
final_df = sales_df.merge(stores_df, left_on = 'store', right_on = 'store_id')

# %%
final_df
# Out:
#         item  sale_amount                      sale_date  sale_id  store  \
# 0          1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1          1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2          1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3          1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4          1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...      ...          ...                            ...      ...    ...
# 912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     10
# 912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     10
# 912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     10
# 912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     10
# 912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     10
#
#                  store_address   store_city  store_id store_state  \
# ...

# %%
final_df = final_df.merge(df, left_on = 'item', right_on = 'item_id')

# %%
final_df
# Out:
#         item  sale_amount                      sale_date  sale_id  store  \
# 0          1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1          1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2          1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3          1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4          1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...      ...          ...                            ...      ...    ...
# 912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     10
# 912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     10
# 912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     10
# 912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     10
# 912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     10
#
#                  store_address   store_city  store_id store_state  \
# ...

# %% [markdown]
# - Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv

# %%
power_df = pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')
